# %% [markdown]
# # ![Screenshot%202019-12-25%20at%2010.58.12%20PM.png](attachment:Screenshot%202019-12-25%20at%2010.58.12%20PM.png)Task 1

# %% [markdown]
# ## 1.
# Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# print("hello world")

# %%
print('Hello World')
s='Hello world'
s
# Out:
# Hello World
# 'Hello world'

# %% [markdown]
# ## 2.![Screenshot%202019-12-26%20at%2012.18.32%20AM.png](attachment:Screenshot%202019-12-26%20at%2012.18.32%20AM.png)
# Write a program which will find all such numbers which are divisible by 7 but are not a multiple
# of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
# comma-separated sequence on a single line.

# %%
li=[]
for i in range(2000,3201):
    if i%7==0 and i%5!=0:
        li.append(i)
    else: continue
for x in li: print(x,end=',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %% [markdown]
# ## 3.![Screenshot%202019-12-26%20at%2012.24.47%20AM.png](attachment:Screenshot%202019-12-26%20at%2012.24.47%20AM.png)
# Write a Python program to accept the user's first and last name and then getting them printed in
# the the reverse order with a space between first name and last name.

# %%
name1=input('Please enter your first name: ')
name2=input('Please enter your last name: ')
print(name1[::-1]+' '+name2[::-1])
# Out:
# Please enter your first name: Siddharth
# Please enter your last name: Vaithinathan
# htrahddiS nahtanihtiaV

# %% [markdown]
# ## 4.![Screenshot%202019-12-26%20at%2012.25.42%20AM.png](attachment:Screenshot%202019-12-26%20at%2012.25.42%20AM.png)
# Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r 3

# %%
import math
d=input('Enter the diameter of sphere:')
r=float(d)/2
V=(4/3)*math.pi*r**3
print('Volume of Sphere: %f'%V)
# Out:
# Enter the diameter of sphere:11
# Volume of Sphere: 696.909970

# %% [markdown]
# # Task 2:
# ## 1.![Screenshot%202019-12-26%20at%2012.35.20%20AM.png](attachment:Screenshot%202019-12-26%20at%2012.35.20%20AM.png)
# Write a program which accepts a sequence of comma-separated numbers from console and
# generate a list.

# %%
li=input('Enter the seq of numbers separated by Commas: ')
list=li.split(',')
flist=[int(i) for i in list]
print(flist)
# Out:
# Enter the seq of numbers separated by Commas: 1,2,3
# [1, 2, 3]

# %% [markdown]
# ## 2.
# ![Screenshot%202019-12-26%20at%204.44.24%20PM.png](attachment:Screenshot%202019-12-26%20at%204.44.24%20PM.png)
# Create the below pattern using nested for loop in Python.
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
#any of these two solution works:
#NESTED FOR loop:
for i in range(6):
    for j in range(i):
        print('*',end = " ")  
    print(end = "\n")
for i in range(4,0,-1):
    for j in range(i):
        print('*',end = " ")
    print(end="\n")
#FOR loop:
'''
for i in range(6):
    print(i*'* ')
for i in range(4,0,-1):
    print(i*'* ')
'''
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# "\nfor i in range(6):\n    print(i*'* ')\nfor i in range(4,0,-1):\n    print(i*'* ')\n"

# %% [markdown]
# ## 3.![Screenshot%202019-12-26%20at%2012.36.13%20AM.png](attachment:Screenshot%202019-12-26%20at%2012.36.13%20AM.png)
# Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
# Input word: AcadGild
# Output: dilGdacA

# %%
name=input('Enter a word: ')
print(name[::-1])
# Out:
# Enter a word: Anusha Siddugari
# iraguddiS ahsunA

# %% [markdown]
# ## 4.
# ![Screenshot%202019-12-26%20at%206.06.17%20PM.png](attachment:Screenshot%202019-12-26%20at%206.06.17%20PM.png)
# Write a Python Program to print the given string in the format specified in the sample output.
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
# SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
# its citizens
# Sample Output:
# WE, THE PEOPLE OF INDIA,
#     having solemnly resolved to constitute India into a SOVEREIGN, !
#         SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#             and to secure to all its citizens

# %%
print('WE, THE PEOPLE OF INDIA,\n \t having solemnly resolved to constitute India into a SOVEREIGN,\n \t \t SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n \t \t \t and to secure to all its citizens')
# Out:
# WE, THE PEOPLE OF INDIA,
#  	 having solemnly resolved to constitute India into a SOVEREIGN,
#  	 	 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#  	 	 	 and to secure to all its citizens
