# %% [markdown]
# # Task 1
# ## 1.
# ### 1.1
# Write a Python Program to implement your own myreduce() function which works exactly like
# Python's built-in function reduce()

# %%
def myreduce(fun,lists):
    output = 0
    for i in range(0,len(lists)):
        output = fun(output,lists[i])
    return output
lists=[]
myreduce(lambda x,y:x+y,lists)
# Out:
# 0

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%2012.44.34%20AM.png](attachment:Screenshot%202020-01-03%20at%2012.44.34%20AM.png)

# %% [markdown]
# ### 1.2
# Write a Python program to implement your own myfilter() function which works exactly like
# Python's built-in function filter()

# %%
def myfilter(fun,listt):
    temp=[]
    out_li=[]
    for i in range(0,len(listt)):
        temp.append(fun(listt[i]))
        
    for j in range(0,len(temp)):
        if temp[j]==True:
            out_li.append(listt[j])
    return out_li

ls=[1,2,3,4,5,6,7,8]
myfilter(lambda x: x%2!=0,ls)
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%2012.45.44%20AM.png](attachment:Screenshot%202020-01-03%20at%2012.45.44%20AM.png)

# %% [markdown]
# ## 2.
# Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xx', 'yy', 'zz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
######
s='ACADGILD'
l=[s[i] for i in range(len(s))]
print(l)

######
s1='xyz'
l1=[j*a for j in s1 for a in range(1,5)]
print(l1)

######
l2=[j*a for a in range(1,5) for j in s1 ]
print(l2)

######
s2=[2,3,4]
l3=[[s2[k]+m] for k in range(len(s2)) for m in range(0,3)]
print(l3)

######
s3=[2,3,4,5]
l4=[[s3[k]+m for k in range(len(s3))] for m in range(0,4)]
print(l4)

######
s4=[1,2,3]
l5=[(a,b) for a in s4 for b in s4 ]
print(l5)
# Out:
# ['A', 'C', 'A', 'D', 'G', 'I', 'L', 'D']
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]

# %% [markdown]
# ##### Output:
# ![Screenshot%202019-12-31%20at%203.46.51%20PM.png](attachment:Screenshot%202019-12-31%20at%203.46.51%20PM.png)

# %% [markdown]
# ## 3.
# Implement a function longestWord() that takes a list of words and returns the longest one.

# %%
name=input('Please enter a list of names:')
name=name.split()
name.sort()
length=[len(x) for x in name]
long=dict(zip(name,length))
#print(long)
mm=max(length)
for k,v in long.items():
    if v ==mm: print(k)
# Out:
# Please enter a list of names:Anu Siddhu Dhruva
# Dhruva
# Siddhu

# %% [markdown]
# ![Screenshot%202020-01-01%20at%2011.08.58%20AM.png](attachment:Screenshot%202020-01-01%20at%2011.08.58%20AM.png)

# %% [markdown]
# # Task 2:
# ## 1.1
# Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
class Triangle:
     def __init__(self,A,B,C):
        self.A = A
        self.B = B
        self.C = C
class Area(Triangle):
        def area_c(self):
            s=float((self.A + self.B + self.C)/2)
            area=float((s*(s-self.A)*(s-self.B)*(s-self.C))**0.5)
            return area
        

A=float(input("Enter the value of a = "))
B=float(input("Enter the value of b = "))
C=float(input("Enter the value of c = "))
if (A+B)>C:
    t = Area(A,B,C)
    print(t.area_c())
else: print('Invalid paramters')
# Out:
# Enter the value of a = 10
# Enter the value of b = 14
# Enter the value of c = 8
# 39.191835884530846

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%203.45.34%20PM.png](attachment:Screenshot%202020-01-03%20at%203.45.34%20PM.png)

# %% [markdown]
# ## 1.2
# Write a function filter_long_words() that takes a list of words and an integer n and returns the list
# of words that are longer than n.

# %%
def filter_long_words(arr_words,N_count):
    ar_l=[len(i) for i in arr_words]
    #print(ar_l)
    long_dict=dict(zip(arr_words,ar_l))
    
    for k,v in long_dict.items():
        if int(v) > int(N_count): print(k)

words = input('Please enter a list of names:')
count = input('Enter a number :')
words = words.split()
filter_long_words(words,count)
# Out:
# Please enter a list of names:Anusha Siddugari Dhruva Dhruva
# Enter a number :6
# Siddugari

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%2012.46.38%20AM.png](attachment:Screenshot%202020-01-03%20at%2012.46.38%20AM.png)

# %% [markdown]
# # 2
# ## 2.1
# Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words.
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
'''
def lengths(lis):
    leng=[len(i) for i in lis]
    print(leng)
liss=input('Please enter a list of words:')
liss=liss.split(',')
print(liss)
lengths(liss)
'''

def lengths(L):
    return len(L)

liss=input('Please enter a list of words:')
liss=liss.split() 
#print(liss)

length=list(map(lengths,liss))
print(length)
# Out:
# Please enter a list of words:Anu Siddhu Dhruva Siddugari
# [3, 6, 6, 9]

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%2012.57.59%20AM.png](attachment:Screenshot%202020-01-03%20at%2012.57.59%20AM.png)

# %% [markdown]
# ## 2.2
# Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is
# a vowel, False otherwise.

# %%
def ifvowel(x):
    if len(x)!=1:
        print('Not a character')
    elif x in ['a','e','i','o','u','A','E','I','O','U']: return True
    else: return False

x=input('Enter a character: ')
ifvowel(x)
# Out:
# Enter a character:
# False

# %% [markdown]
# #### Passed empty as input in above scenario

# %% [markdown]
# ### OUTPUT
# ![Screenshot%202020-01-03%20at%2012.47.44%20AM.png](attachment:Screenshot%202020-01-03%20at%2012.47.44%20AM.png)

# %% [markdown]
# #### Passed a space as input in above scenario
